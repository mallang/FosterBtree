# %% [markdown]
# # Generate csv file as input

# %%
import os
import subprocess
import glob
import pandas as pd
import matplotlib.pyplot as plt
import re
import filecmp

# Use the custom style
plt.style.use('../custom_plt_sytle.mplstyle')

# Number of runs per workload

entries = 1000
versions = 200
partitions = 4

csv_dir = format("./csv_%dentries_%dversions" % (entries, versions))
print(csv_dir)
os.makedirs(csv_dir, exist_ok=True)

print("Deleted existing CSV files.")
# Clean up old CSV files in workload and csv directories
for f in glob.glob(os.path.join(csv_dir, '*.csv')):
    os.remove(f)

# Run gen_data.py to generate data_multiversion.csv
print("Running gen_data_multiversion.py...")
subprocess.run([
    'python3', './gen_py/gen_data_ts_partititoned.py',
    '-o', os.path.join(csv_dir, 'data_multiversion.csv'),
    '-n', str(entries), '-k', '100', '-p', '8', '-vmin', '892', '-vmax', '892', '-s', '500',
    '-vc', str(versions), '-par', str(partitions)
], check=True)
print("data_multiversion.csv generated.")

# Generate workloads (txs and ops files)
print("Generating workloads...")
subprocess.run(['python3', './gen_py/gen_workloads_get_mv.py',
                '-od', csv_dir,
                '-par', str(partitions)
                ], check=True)
print("Workloads generated.")
# Out:
# ./csv_1000entries_200versions
# Deleted existing CSV files.
# Running gen_data_multiversion.py...
# data_multiversion.csv generated.
# Generating workloads...
# generating get workloads... output dir ./csv_1000entries_200versions
# Generated mixed operations in ./csv_1000entries_200versions/hget_ratio000_ops.csv
# Generated mixed operations in ./csv_1000entries_200versions/hget_ratio020_ops.csv
# Generated mixed operations in ./csv_1000entries_200versions/hget_ratio040_ops.csv
# Generated mixed operations in ./csv_1000entries_200versions/hget_ratio060_ops.csv
# Generated mixed operations in ./csv_1000entries_200versions/hget_ratio080_ops.csv
# Generated mixed operations in ./csv_1000entries_200versions/hget_ratio100_ops.csv
# Workloads generated.

# %% [markdown]
# # Run benchmark with statistics (Only chain implementation support statistics now)

# %%
import os
import subprocess
import glob
import pandas as pd
import matplotlib.pyplot as plt
import re
from IPython.display import display, Markdown

# Use the custom style
plt.style.use('../custom_plt_sytle.mplstyle')


# Number of runs per workload
number_of_runs = 1

workload_dir = './workload'
csv_dir = format("./csv_%dentries_%dversions" % (entries, versions))

# Build the binary to ensure it's up-to-date
print("Building hash_join_bench with cargo build --release...")
myenv = os.environ.copy()
myenv["RUSTFLAGS"] = "-Awarnings"
subprocess.run(['cargo', 'build', '--release', '--bin', 'hash_join_bench_mixed_get'], check=True, env=myenv)
print("Build completed.")

binary = '../../../target/release/hash_join_bench_mixed_get'
data_file_prefix = os.path.join(csv_dir, 'data_multiversion.csv')
scan_ops_file = os.path.join(csv_dir, 'scan_ops.csv')

# Find all workload ops files in csv directory
ops_files = glob.glob(os.path.join(csv_dir, '*_ops.csv'))
ops_files.sort()

results = []  # will hold dicts of {workload, run, rust_load_ns, hj_load_ns, rust_exec_ns, hj_exec_ns, recent_get_ns, history_get_ns}

for ops_path in ops_files:
    workload_name = os.path.splitext(os.path.basename(ops_path))[0].replace('_ops','')
    
    # Corresponding recent/history after ops files
    recent_data_after_ops_file = os.path.join(csv_dir, f'{workload_name}_recent_data_after_ops.csv')
    history_data_after_ops_file = os.path.join(csv_dir, f'{workload_name}_history_data_after_ops.csv')

    # Run the benchmark multiple times for each workload
    for run_id in range(1, number_of_runs+1):
        print(f"Running benchmark for workload {workload_name}, run {run_id}...")
        cmd = [
            binary,
            '-df', data_file_prefix,
            '-of', ops_path,
            '-rdf', recent_data_after_ops_file,
            '-hdf', history_data_after_ops_file,
            '-sof', scan_ops_file
        ]

        print("cmd:", cmd)

        completed = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        if completed.returncode != 0:
            print(f"Benchmark failed for workload {workload_name}, run {run_id}:")
            print(completed.stderr)
            continue

        output = completed.stdout
        print("benchmark run output:", output)

        # Extract statistics block (which includes our GET time metrics)
        pattern = r"===STAT_START===\n(.*?)\n===STAT_END==="
        match = re.search(pattern, output, re.DOTALL)
        stat_output = ""
        recent_get_time_ns = None
        history_get_time_ns = None
        if match:
            stat_output = match.group(1)
            print("Extracted Statistics:")
            print(stat_output)
            display(Markdown(f"```\n{stat_output}\n```"))
            # Parse recent and history get times from the statistics output
            for line in stat_output.splitlines():
                if line.startswith("Total time spent in recent_chain.get():"):
                    m = re.search(r"Total time spent in recent_chain\.get\(\): (\d+) ns", line)
                    if m:
                        recent_get_time_ns = int(m.group(1))
                elif line.startswith("Total time spent in history_chain.get():"):
                    m = re.search(r"Total time spent in history_chain\.get\(\): (\d+) ns", line)
                    if m:
                        history_get_time_ns = int(m.group(1))
        else:
            print("Could not find statistics markers in the output.")

        # Parse other times (loading and execution times)
        rust_load_time_ns = None
        hj_load_time_ns = None
        rust_time_ns = None
        hj_execute_time_ns = None

        for line in output.splitlines():
            if line.startswith("Loaded") and "Rust HashMap" in line:
                m = re.search(r'Loaded \d+ entries into Rust HashMap in (\d+) ns', line)
                if m:
                    rust_load_time_ns = int(m.group(1))
            elif line.startswith("Loaded") and "HashJoinTable" in line:
                m = re.search(r'Loaded \d+ entries into HashJoinTable in (\d+) ns', line)
                if m:
                    hj_load_time_ns = int(m.group(1))
            elif line.startswith("Rust HashMap: Executed"):
                m = re.search(r'Executed \d+ operations in (\d+) ns', line)
                if m:
                    rust_time_ns = int(m.group(1))
            elif line.startswith("HashJoinTable: Executed"):
                m = re.search(r'Executed \d+ operations in (\d+) ns', line)
                if m:
                    hj_execute_time_ns = int(m.group(1))

        if (rust_time_ns is None or hj_execute_time_ns is None or
            rust_load_time_ns is None or hj_load_time_ns is None):
            print("Warning: Could not parse all times from output for this run:")
            print(output)
        else:
            results.append({
                'workload': workload_name,
                'run': run_id,
                'rust_load_ns': rust_load_time_ns,
                'hj_load_ns': hj_load_time_ns,
                'rust_exec_ns': rust_time_ns,
                'hj_exec_ns': hj_execute_time_ns,
                'recent_get_ns': recent_get_time_ns if recent_get_time_ns is not None else 0,
                'history_get_ns': history_get_time_ns if history_get_time_ns is not None else 0,
            })

print("Benchmarking completed.")
print("results:", results)
df = pd.DataFrame(results)

if df.empty:
    print("No results were parsed. Check the output format or regex patterns.")
else:
    # Compute means and standard deviations for each workload
    stats = df.groupby('workload').agg({
        'rust_load_ns': ['mean', 'std'],
        'hj_load_ns': ['mean', 'std'],
        'rust_exec_ns': ['mean', 'std'],
        'hj_exec_ns': ['mean', 'std'],
        'recent_get_ns': ['mean', 'std'],
        'history_get_ns': ['mean', 'std']
    })

    # Flatten the MultiIndex columns
    stats.columns = [
        'rust_load_mean', 'rust_load_std',
        'hj_load_mean', 'hj_load_std',
        'rust_exec_mean', 'rust_exec_std',
        'hj_exec_mean', 'hj_exec_std',
        'recent_get_mean', 'recent_get_std',
        'history_get_mean', 'history_get_std'
    ]
    stats = stats.reset_index()
    stats = stats.sort_values('workload')

    # Convert nanoseconds to milliseconds for readability
    stats['rust_load_mean_ms'] = stats['rust_load_mean'] / 1_000_000
    stats['rust_exec_mean_ms'] = stats['rust_exec_mean'] / 1_000_000
    stats['hj_load_mean_ms'] = stats['hj_load_mean'] / 1_000_000
    stats['hj_exec_mean_ms'] = stats['hj_exec_mean'] / 1_000_000
    stats['recent_get_mean_ms'] = stats['recent_get_mean'] / 1_000_000
    stats['history_get_mean_ms'] = stats['history_get_mean'] / 1_000_000

    # Print the averaged results
    print("Averaged Results:")
    for i, row in stats.iterrows():
        print(f"Workload: {row['workload']}")
        print(f"  Rust HashMap: load={row['rust_load_mean_ms']:.2f} ms, exec={row['rust_exec_mean_ms']:.2f} ms")
        print(f"  MvccHashJoinTable: load={row['hj_load_mean_ms']:.2f} ms, exec={row['hj_exec_mean_ms']:.2f} ms")
        print(f"  recent_chain.get(): {row['recent_get_mean_ms']:.2f} ms, history_chain.get(): {row['history_get_mean_ms']:.2f} ms")

    # 1) Plot Execution Times Comparison
    plt.figure(figsize=(10,6))
    X = range(len(stats))
    plt.errorbar(X, stats['rust_exec_mean_ms'], yerr=stats['rust_exec_std']/1_000_000, fmt='o-', label='HashTable with SingleChain Exec')
    plt.errorbar(X, stats['hj_exec_mean_ms'], yerr=stats['hj_exec_std']/1_000_000, fmt='o-', label='MvccHashJoinTable Exec')
    plt.xticks(X, stats['workload'], rotation=45)
    plt.xlabel('Workload')
    plt.ylabel('Execution Time (ms)')
    plt.title('Benchmark Comparison (Execution Times)')
    plt.legend()
    for i, x_val in enumerate(X):
        plt.text(x_val, stats['rust_exec_mean_ms'].iloc[i] + 0.05, f"{stats['rust_exec_mean_ms'].iloc[i]:.2f} ms", ha='center', color='blue')
        plt.text(x_val, stats['hj_exec_mean_ms'].iloc[i] + 0.05, f"{stats['hj_exec_mean_ms'].iloc[i]:.2f} ms", ha='center', color='orange')
    plt.tight_layout()
    plt.show()

    # 2) Plot Loading Times Comparison
    plt.figure(figsize=(10,6))
    plt.errorbar(X, stats['rust_load_mean_ms'], yerr=stats['rust_load_std']/1_000_000, fmt='o-', label='HashTable with SingleChain Load')
    plt.errorbar(X, stats['hj_load_mean_ms'], yerr=stats['hj_load_std']/1_000_000, fmt='o-', label='MvccHashJoinTable Load')
    plt.xticks(X, stats['workload'], rotation=45)
    plt.xlabel('Workload')
    plt.ylabel('Loading Time (ms)')
    plt.title('Benchmark Comparison (Loading Times)')
    plt.legend()
    for i, x_val in enumerate(X):
        plt.text(x_val, stats['rust_load_mean_ms'].iloc[i] + 0.05, f"{stats['rust_load_mean_ms'].iloc[i]:.2f} ms", ha='center', color='blue')
        plt.text(x_val, stats['hj_load_mean_ms'].iloc[i] + 0.05, f"{stats['hj_load_mean_ms'].iloc[i]:.2f} ms", ha='center', color='orange')
    plt.tight_layout()
    plt.show()

    # 3) Plot GET Times Comparison (recent vs history)
    plt.figure(figsize=(10,6))
    plt.errorbar(X, stats['recent_get_mean_ms'], yerr=stats['recent_get_std']/1_000_000, fmt='o-', label='recent_chain.get()')
    plt.errorbar(X, stats['history_get_mean_ms'], yerr=stats['history_get_std']/1_000_000, fmt='o-', label='history_chain.get()')
    plt.xticks(X, stats['workload'], rotation=45)
    plt.xlabel('Workload')
    plt.ylabel('Total GET Time (ms)')
    plt.title('Benchmark Comparison (GET Times)')
    plt.legend()
    for i, x_val in enumerate(X):
        plt.text(x_val, stats['recent_get_mean_ms'].iloc[i] + 0.05, f"{stats['recent_get_mean_ms'].iloc[i]:.2f} ms", ha='center', color='blue')
        plt.text(x_val, stats['history_get_mean_ms'].iloc[i] + 0.05, f"{stats['history_get_mean_ms'].iloc[i]:.2f} ms", ha='center', color='orange')
    plt.tight_layout()
    plt.show()

    # 4) Plot Execution & GET Times (smaller annotation font)
    plt.figure(figsize=(10,6))
    X = range(len(stats))
    plt.errorbar(X, stats['rust_exec_mean_ms'], 
                 yerr=stats['rust_exec_std']/1_000_000, 
                 fmt='o-', 
                 label='HashTable with SingleChain Exec')
    plt.errorbar(X, stats['hj_exec_mean_ms'], 
                 yerr=stats['hj_exec_std']/1_000_000, 
                 fmt='s-', 
                 label='MvccHashJoinTable Exec')
    plt.errorbar(X, stats['recent_get_mean_ms'], 
                 yerr=stats['recent_get_std']/1_000_000, 
                 fmt='^-', 
                 label='recent_chain.get()')
    plt.errorbar(X, stats['history_get_mean_ms'], 
                 yerr=stats['history_get_std']/1_000_000, 
                 fmt='v-', 
                 label='history_chain.get()')
    plt.xticks(X, stats['workload'], rotation=45)
    plt.xlabel('Workload')
    plt.ylabel('Time (ms)')
    plt.title('Benchmark Comparison: Execution & GET Times')
    plt.legend()

    # ---- Annotate data points (smaller font) ----
    for i, x_val in enumerate(X):
        # Rust Exec
        plt.text(
            x_val,
            stats['rust_exec_mean_ms'].iloc[i] + 0.05,
            f"{stats['rust_exec_mean_ms'].iloc[i]:.2f} ms",
            ha='center',
            color='blue',
            fontsize=9
        )
        # MvccHashJoinTable Exec
        plt.text(
            x_val,
            stats['hj_exec_mean_ms'].iloc[i] + 0.05,
            f"{stats['hj_exec_mean_ms'].iloc[i]:.2f} ms",
            ha='center',
            color='green',
            fontsize=9
        )
        # recent_chain.get()
        plt.text(
            x_val,
            stats['recent_get_mean_ms'].iloc[i] + 0.05,
            f"{stats['recent_get_mean_ms'].iloc[i]:.2f} ms",
            ha='center',
            color='red',
            fontsize=9
        )
        # history_chain.get()
        plt.text(
            x_val,
            stats['history_get_mean_ms'].iloc[i] + 0.05,
            f"{stats['history_get_mean_ms'].iloc[i]:.2f} ms",
            ha='center',
            color='orange',
            fontsize=9
        )
    # ---------------------------------------------

    plt.tight_layout()
    plt.show()

    # 5) Plot Execution & GET Times (bigger annotation font)
    plt.figure(figsize=(10,6))
    X = range(len(stats))

    # Plot each series with error bars and custom markers
    plt.errorbar(
        X, stats['rust_exec_mean_ms'], 
        yerr=stats['rust_exec_std']/1_000_000, 
        fmt='o-', 
        label='HashTable with SingleChain Exec',
        capsize=5
    )
    plt.errorbar(
        X, stats['hj_exec_mean_ms'], 
        yerr=stats['hj_exec_std']/1_000_000, 
        fmt='s-', 
        label='MvccHashJoinTable Exec',
        capsize=5
    )
    plt.errorbar(
        X, stats['recent_get_mean_ms'], 
        yerr=stats['recent_get_std']/1_000_000, 
        fmt='^-', 
        label='recent_chain.get()',
        capsize=5
    )
    plt.errorbar(
        X, stats['history_get_mean_ms'], 
        yerr=stats['history_get_std']/1_000_000, 
        fmt='v-', 
        label='history_chain.get()',
        capsize=5
    )

    # Set x-ticks with adjusted font size
    plt.xticks(X, stats['workload'], rotation=45, fontsize=12)
    plt.xlabel('Workload', fontsize=14)
    plt.ylabel('Time (ms)', fontsize=14)
    plt.title('Benchmark Comparison: Execution & GET Times', fontsize=16)
    plt.legend(fontsize=12)

    # Annotate each data point (bigger font)
    for i, x_val in enumerate(X):
        plt.text(
            x_val, stats['rust_exec_mean_ms'].iloc[i] + 0.05, 
            f"{stats['rust_exec_mean_ms'].iloc[i]:.2f} ms", 
            ha='center', color='blue', fontsize=10
        )
        plt.text(
            x_val, stats['hj_exec_mean_ms'].iloc[i] + 0.05, 
            f"{stats['hj_exec_mean_ms'].iloc[i]:.2f} ms", 
            ha='center', color='green', fontsize=10
        )
        plt.text(
            x_val, stats['recent_get_mean_ms'].iloc[i] + 0.05, 
            f"{stats['recent_get_mean_ms'].iloc[i]:.2f} ms", 
            ha='center', color='red', fontsize=10
        )
        plt.text(
            x_val, stats['history_get_mean_ms'].iloc[i] + 0.05, 
            f"{stats['history_get_mean_ms'].iloc[i]:.2f} ms", 
            ha='center', color='orange', fontsize=10
        )

    plt.tight_layout()
    plt.show()
# Out:
# Building hash_join_bench with cargo build --release...
# Build completed.
# Running benchmark for workload hget_ratio000, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get', '-df', './csv/data_multiversion.csv', '-of', './csv/hget_ratio000_ops.csv', '-rdf', './csv/hget_ratio000_recent_data_after_ops.csv', '-hdf', './csv/hget_ratio000_history_data_after_ops.csv', '-sof', './csv/scan_ops.csv']
# benchmark run output: Data file: ./csv/data_multiversion.csv
# Ops file: ./csv/hget_ratio000_ops.csv
#
# Loaded 100 entries with 10 versions into HashJoinTable in 320356 ns
#
# HashJoinTable: Executed 11000 operations in 5801757 ns
#
# ===STAT_START===
#
# Could not find statistics markers in the output.
# Warning: Could not parse all times from output for this run:
# Data file: ./csv/data_multiversion.csv
# Ops file: ./csv/hget_ratio000_ops.csv
#
# Loaded 100 entries with 10 versions into HashJoinTable in 320356 ns
#
# HashJoinTable: Executed 11000 operations in 5801757 ns
#
# ===STAT_START===
#
# Running benchmark for workload hget_ratio020, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get', '-df', './csv/data_multiversion.csv', '-of', './csv/hget_ratio020_ops.csv', '-rdf', './csv/hget_ratio020_recent_data_after_ops.csv', '-hdf', './csv/hget_ratio020_history_data_after_ops.csv', '-sof', './csv/scan_ops.csv']
#     Finished `release` profile [optimized + debuginfo] target(s) in 0.05s
# benchmark run output: Data file: ./csv/data_multiversion.csv
# Ops file: ./csv/hget_ratio020_ops.csv
#
# Loaded 100 entries with 10 versions into HashJoinTable in 328873 ns
#
# HashJoinTable: Executed 11000 operations in 5844422 ns
#
# ===STAT_START===
#
# Could not find statistics markers in the output.
# Warning: Could not parse all times from output for this run:
# Data file: ./csv/data_multiversion.csv
# Ops file: ./csv/hget_ratio020_ops.csv
#
# Loaded 100 entries with 10 versions into HashJoinTable in 328873 ns
#
# HashJoinTable: Executed 11000 operations in 5844422 ns
#
# ===STAT_START===
#
# Running benchmark for workload hget_ratio040, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get', '-df', './csv/data_multiversion.csv', '-of', './csv/hget_ratio040_ops.csv', '-rdf', './csv/hget_ratio040_recent_data_after_ops.csv', '-hdf', './csv/hget_ratio040_history_data_after_ops.csv', '-sof', './csv/scan_ops.csv']
# benchmark run output: Data file: ./csv/data_multiversion.csv
# Ops file: ./csv/hget_ratio040_ops.csv
#
# Loaded 100 entries with 10 versions into HashJoinTable in 327710 ns
#
# HashJoinTable: Executed 11000 operations in 5925713 ns
#
# ===STAT_START===
#
# Could not find statistics markers in the output.
# Warning: Could not parse all times from output for this run:
# Data file: ./csv/data_multiversion.csv
# Ops file: ./csv/hget_ratio040_ops.csv
#
# Loaded 100 entries with 10 versions into HashJoinTable in 327710 ns
#
# HashJoinTable: Executed 11000 operations in 5925713 ns
#
# ===STAT_START===
#
# Running benchmark for workload hget_ratio060, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get', '-df', './csv/data_multiversion.csv', '-of', './csv/hget_ratio060_ops.csv', '-rdf', './csv/hget_ratio060_recent_data_after_ops.csv', '-hdf', './csv/hget_ratio060_history_data_after_ops.csv', '-sof', './csv/scan_ops.csv']
# benchmark run output: Data file: ./csv/data_multiversion.csv
# Ops file: ./csv/hget_ratio060_ops.csv
#
# Loaded 100 entries with 10 versions into HashJoinTable in 330510 ns
#
# HashJoinTable: Executed 11000 operations in 5893007 ns
#
# ===STAT_START===
#
# Could not find statistics markers in the output.
# Warning: Could not parse all times from output for this run:
# Data file: ./csv/data_multiversion.csv
# Ops file: ./csv/hget_ratio060_ops.csv
#
# Loaded 100 entries with 10 versions into HashJoinTable in 330510 ns
#
# HashJoinTable: Executed 11000 operations in 5893007 ns
#
# ===STAT_START===
#
# Running benchmark for workload hget_ratio080, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get', '-df', './csv/data_multiversion.csv', '-of', './csv/hget_ratio080_ops.csv', '-rdf', './csv/hget_ratio080_recent_data_after_ops.csv', '-hdf', './csv/hget_ratio080_history_data_after_ops.csv', '-sof', './csv/scan_ops.csv']
# benchmark run output: Data file: ./csv/data_multiversion.csv
# Ops file: ./csv/hget_ratio080_ops.csv
#
# Loaded 100 entries with 10 versions into HashJoinTable in 347694 ns
#
# HashJoinTable: Executed 11000 operations in 6108557 ns
#
# ===STAT_START===
#
# Could not find statistics markers in the output.
# Warning: Could not parse all times from output for this run:
# Data file: ./csv/data_multiversion.csv
# Ops file: ./csv/hget_ratio080_ops.csv
#
# Loaded 100 entries with 10 versions into HashJoinTable in 347694 ns
#
# HashJoinTable: Executed 11000 operations in 6108557 ns
#
# ===STAT_START===
#
# Running benchmark for workload hget_ratio100, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get', '-df', './csv/data_multiversion.csv', '-of', './csv/hget_ratio100_ops.csv', '-rdf', './csv/hget_ratio100_recent_data_after_ops.csv', '-hdf', './csv/hget_ratio100_history_data_after_ops.csv', '-sof', './csv/scan_ops.csv']
# benchmark run output: Data file: ./csv/data_multiversion.csv
# Ops file: ./csv/hget_ratio100_ops.csv
#
# Loaded 100 entries with 10 versions into HashJoinTable in 336873 ns
#
# HashJoinTable: Executed 11000 operations in 5850713 ns
#
# ===STAT_START===
#
# Could not find statistics markers in the output.
# Warning: Could not parse all times from output for this run:
# Data file: ./csv/data_multiversion.csv
# Ops file: ./csv/hget_ratio100_ops.csv
#
# Loaded 100 entries with 10 versions into HashJoinTable in 336873 ns
#
# HashJoinTable: Executed 11000 operations in 5850713 ns
#
# ===STAT_START===
#
# Benchmarking completed.
# results: []
# No results were parsed. Check the output format or regex patterns.

# %% [markdown]
# # Run benchmark without statistics

# %%
import os
import subprocess
import glob
import pandas as pd
import matplotlib.pyplot as plt
import re
from IPython.display import display, Markdown

# Use the custom style
plt.style.use('../custom_plt_sytle.mplstyle')

# Number of runs per workload
number_of_runs = 1
entries = 1000
versions = 200
partitions = 4
csv_dir = format("./csv_%dentries_%dversions" % (entries, versions))
# csv_dir = "./csv"

print(f"csv_dir is {csv_dir}")
# Build the binary to ensure it's up-to-date
print("Building hash_join_bench with cargo build --release...")
myenv = os.environ.copy()
myenv["RUSTFLAGS"] = "-Awarnings"
subprocess.run(['cargo', 'build', '--release', '--bin', 'hash_join_bench_mixed_get_repair'], check=True, env=myenv)
print("Build completed.")

binary = '../../../target/release/hash_join_bench_mixed_get_repair'
data_file_prefix = os.path.join(csv_dir, 'data_multiversion')
scan_ops_file = os.path.join(csv_dir, 'scan_ops.csv')

# Find all workload ops files in csv directory
ops_files = glob.glob(os.path.join(csv_dir, '*_ops.csv'))
ops_files.sort()

results = []  # will hold dicts of {workload, run, rust_load_ns, hj_load_ns, rust_exec_ns, hj_exec_ns, recent_get_ns, history_get_ns}
hash_join_table_type_list = ['ts_partitioned', 'ts_partitioned_read_repair', 'no_partition', 'no_partition_read_repair']
for ops_path in ops_files:
    workload_name = os.path.splitext(os.path.basename(ops_path))[0].replace('_ops','')
    
    for hash_join_table_type in hash_join_table_type_list:
        # Run the benchmark multiple times for each workload
        for run_id in range(1, number_of_runs+1):
            print(f"Running benchmark for workload {workload_name}, table type {hash_join_table_type}, run {run_id}...")
            cmd = [
                binary,
                '-df', data_file_prefix,
                '-of', ops_path,
                '-t', hash_join_table_type
            ]
            if 'ts_partitioned' in hash_join_table_type:
                cmd += ['-p']
            if "read_repair" in hash_join_table_type:
                cmd += ['-rr']

            print("cmd:", cmd)

            completed = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
            if completed.returncode != 0:
                print(f"Benchmark failed for workload {workload_name}, run {run_id}:")
                print(completed.stderr)
                print(completed.stdout)
                continue

            output = completed.stdout
            print("benchmark run output:", output)

            # Parse other times (loading and execution times)
            hj_load_time_ns = None
            hj_execute_time_ns = None

            for line in output.splitlines():
                if line.startswith("Loaded") and "HashJoinTable" in line:
                    m = re.search(r'Loaded (\d+) entries with (\d+) versions into HashJoinTable in (\d+) ns', line)
                    if m:
                        hj_load_time_ns = int(m.group(3))
                elif line.startswith("HashJoinTable: Executed"):
                    m = re.search(r'Executed \d+ operations in (\d+) ns', line)
                    if m:
                        hj_execute_time_ns = int(m.group(1))

            if (hj_execute_time_ns is None or hj_load_time_ns is None):
                print("Warning: Could not parse all times from output for this run:")
                print(output)
            else:
                results.append({
                    'workload': workload_name,
                    'hash_join_table_type': hash_join_table_type,
                    'run': run_id,
                    'hj_load_ns': hj_load_time_ns,
                    'hj_exec_ns': hj_execute_time_ns,
                })

print("Benchmarking completed.")
print("results:", results)
df = pd.DataFrame(results)

if df.empty:
    print("No results were parsed. Check the output format or regex patterns.")
else:
    # Compute means and standard deviations for each workload
    stats = df.groupby(['workload', 'hash_join_table_type']).agg({
        'hj_load_ns': ['mean', 'std'],
        'hj_exec_ns': ['mean', 'std'],
    })

    # Flatten the MultiIndex columns
    stats.columns = [
        'hj_load_mean', 'hj_load_std',
        'hj_exec_mean', 'hj_exec_std',
    ]
    stats = stats.reset_index()
    stats = stats.sort_values('workload')

    # Convert nanoseconds to milliseconds for readability
    stats['hj_load_mean_ms'] = stats['hj_load_mean'] / 1_000_000
    stats['hj_exec_mean_ms'] = stats['hj_exec_mean'] / 1_000_000

    # Print the averaged results
    print("Averaged Results:")
    for i, row in stats.iterrows():
        print(f"Workload: {row['workload']}")
        print(f"  MvccHashJoinTable: load={row['hj_load_mean_ms']:.2f} ms, exec={row['hj_exec_mean_ms']:.2f} ms")

    # 1) Plot Execution Times Comparison
    plt.figure(figsize=(10,6))
    bar_width = 0.2
    workloads = stats['workload'].unique()
    X = range(len(workloads))

    for hash_join_table_type, group in stats.groupby('hash_join_table_type'):
        plt.errorbar(X, group['hj_exec_mean_ms'], yerr=group['hj_exec_std']/1_000_000, fmt='o-', label=f'{hash_join_table_type} Exec')

    plt.xticks(X, workloads, rotation=45)
    plt.xlabel('Workload')
    plt.ylabel('Execution Time (ms)')
    plt.title('Benchmark Comparison (Execution Times)')
    plt.legend()

    for i, workload in enumerate(workloads):
        for hash_join_table_type, group in stats.groupby('hash_join_table_type'):
            y_val = group[group['workload'] == workload]['hj_exec_mean_ms'].values[0]
            plt.text(i, y_val + 0.05, f"{y_val:.2f} ms", ha='center', color='orange')

    plt.tight_layout()
    plt.show()

    # 2) Plot Loading Times Comparison
    plt.figure(figsize=(10,6))

    for hash_join_table_type, group in stats.groupby('hash_join_table_type'):
        plt.errorbar(X, group['hj_load_mean_ms'], yerr=group['hj_load_std']/1_000_000, fmt='o-', label=f'{hash_join_table_type} Load')

    plt.xticks(X, workloads, rotation=45)
    plt.xlabel('Workload')
    plt.ylabel('Loading Time (ms)')
    plt.title('Benchmark Comparison (Loading Times)')
    plt.legend()

    for i, workload in enumerate(workloads):
        for hash_join_table_type, group in stats.groupby('hash_join_table_type'):
            y_val = group[group['workload'] == workload]['hj_load_mean_ms'].values[0]
            plt.text(i, y_val + 0.05, f"{y_val:.2f} ms", ha='center', color='orange')

    plt.tight_layout()
    plt.show()
# Out:
# csv_dir is ./csv_1000entries_200versions
# Building hash_join_bench with cargo build --release...
# Build completed.
# Running benchmark for workload hget_ratio000, table type ts_partitioned, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio000_ops.csv', '-t', 'ts_partitioned', '-p']
#     Finished `release` profile [optimized + debuginfo] target(s) in 0.03s
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio000_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 140528256 ns
#
# HashJoinTable: Executed 11000 operations in 84540075 ns
#
#
# Running benchmark for workload hget_ratio000, table type ts_partitioned_read_repair, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio000_ops.csv', '-t', 'ts_partitioned_read_repair', '-p', '-rr']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio000_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 139562256 ns
#
# HashJoinTable: Executed 11000 operations in 107546554 ns
#
#
# Running benchmark for workload hget_ratio000, table type no_partition, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio000_ops.csv', '-t', 'no_partition']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio000_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 116863169 ns
#
# HashJoinTable: Executed 11000 operations in 331142715 ns
#
#
# Running benchmark for workload hget_ratio000, table type no_partition_read_repair, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio000_ops.csv', '-t', 'no_partition_read_repair', '-rr']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio000_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 117366218 ns
#
# HashJoinTable: Executed 11000 operations in 140735263 ns
#
#
# Running benchmark for workload hget_ratio020, table type ts_partitioned, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio020_ops.csv', '-t', 'ts_partitioned', '-p']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio020_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 139867244 ns
#
# HashJoinTable: Executed 11000 operations in 86983969 ns
#
#
# Running benchmark for workload hget_ratio020, table type ts_partitioned_read_repair, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio020_ops.csv', '-t', 'ts_partitioned_read_repair', '-p', '-rr']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio020_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 148718817 ns
#
# HashJoinTable: Executed 11000 operations in 105389526 ns
#
#
# Running benchmark for workload hget_ratio020, table type no_partition, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio020_ops.csv', '-t', 'no_partition']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio020_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 119496791 ns
#
# HashJoinTable: Executed 11000 operations in 313220033 ns
#
#
# Running benchmark for workload hget_ratio020, table type no_partition_read_repair, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio020_ops.csv', '-t', 'no_partition_read_repair', '-rr']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio020_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 118624237 ns
#
# HashJoinTable: Executed 11000 operations in 135211427 ns
#
#
# Running benchmark for workload hget_ratio040, table type ts_partitioned, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio040_ops.csv', '-t', 'ts_partitioned', '-p']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio040_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 140738517 ns
#
# HashJoinTable: Executed 11000 operations in 89520899 ns
#
#
# Running benchmark for workload hget_ratio040, table type ts_partitioned_read_repair, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio040_ops.csv', '-t', 'ts_partitioned_read_repair', '-p', '-rr']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio040_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 141840950 ns
#
# HashJoinTable: Executed 11000 operations in 113614065 ns
#
#
# Running benchmark for workload hget_ratio040, table type no_partition, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio040_ops.csv', '-t', 'no_partition']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio040_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 118542650 ns
#
# HashJoinTable: Executed 11000 operations in 350659333 ns
#
#
# Running benchmark for workload hget_ratio040, table type no_partition_read_repair, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio040_ops.csv', '-t', 'no_partition_read_repair', '-rr']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio040_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 119527104 ns
#
# HashJoinTable: Executed 11000 operations in 147080764 ns
#
#
# Running benchmark for workload hget_ratio060, table type ts_partitioned, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio060_ops.csv', '-t', 'ts_partitioned', '-p']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio060_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 139796326 ns
#
# HashJoinTable: Executed 11000 operations in 87989068 ns
#
#
# Running benchmark for workload hget_ratio060, table type ts_partitioned_read_repair, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio060_ops.csv', '-t', 'ts_partitioned_read_repair', '-p', '-rr']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio060_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 143224188 ns
#
# HashJoinTable: Executed 11000 operations in 108608144 ns
#
#
# Running benchmark for workload hget_ratio060, table type no_partition, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio060_ops.csv', '-t', 'no_partition']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio060_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 117101456 ns
#
# HashJoinTable: Executed 11000 operations in 358268378 ns
#
#
# Running benchmark for workload hget_ratio060, table type no_partition_read_repair, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio060_ops.csv', '-t', 'no_partition_read_repair', '-rr']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio060_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 117132044 ns
#
# HashJoinTable: Executed 11000 operations in 144730465 ns
#
#
# Running benchmark for workload hget_ratio080, table type ts_partitioned, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio080_ops.csv', '-t', 'ts_partitioned', '-p']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio080_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 139114596 ns
#
# HashJoinTable: Executed 11000 operations in 92438609 ns
#
#
# Running benchmark for workload hget_ratio080, table type ts_partitioned_read_repair, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio080_ops.csv', '-t', 'ts_partitioned_read_repair', '-p', '-rr']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio080_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 139353542 ns
#
# HashJoinTable: Executed 11000 operations in 106710974 ns
#
#
# Running benchmark for workload hget_ratio080, table type no_partition, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio080_ops.csv', '-t', 'no_partition']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio080_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 117303467 ns
#
# HashJoinTable: Executed 11000 operations in 358353721 ns
#
#
# Running benchmark for workload hget_ratio080, table type no_partition_read_repair, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio080_ops.csv', '-t', 'no_partition_read_repair', '-rr']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio080_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 117104727 ns
#
# HashJoinTable: Executed 11000 operations in 137597682 ns
#
#
# Running benchmark for workload hget_ratio100, table type ts_partitioned, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio100_ops.csv', '-t', 'ts_partitioned', '-p']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio100_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 139700825 ns
#
# HashJoinTable: Executed 11000 operations in 87899906 ns
#
#
# Running benchmark for workload hget_ratio100, table type ts_partitioned_read_repair, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio100_ops.csv', '-t', 'ts_partitioned_read_repair', '-p', '-rr']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio100_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 138427268 ns
#
# HashJoinTable: Executed 11000 operations in 104412925 ns
#
#
# Running benchmark for workload hget_ratio100, table type no_partition, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio100_ops.csv', '-t', 'no_partition']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio100_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 117835211 ns
#
# HashJoinTable: Executed 11000 operations in 357854071 ns
#
#
# Running benchmark for workload hget_ratio100, table type no_partition_read_repair, run 1...
# cmd: ['../../../target/release/hash_join_bench_mixed_get_repair', '-df', './csv_1000entries_200versions/data_multiversion', '-of', './csv_1000entries_200versions/hget_ratio100_ops.csv', '-t', 'no_partition_read_repair', '-rr']
# benchmark run output: Data file prefix: ./csv_1000entries_200versions/data_multiversion
# Ops file: ./csv_1000entries_200versions/hget_ratio100_ops.csv
#
# Loaded 50000 entries into HashJoinTable with max ts 49
# Loaded 50000 entries into HashJoinTable with max ts 99
# Loaded 50000 entries into HashJoinTable with max ts 149
# Loaded 50000 entries into HashJoinTable with max ts 199
# Loaded 1000 entries with 200 versions into HashJoinTable in 117378226 ns
#
# HashJoinTable: Executed 11000 operations in 138930229 ns
#
#
# Benchmarking completed.
# results: [{'workload': 'hget_ratio000', 'hash_join_table_type': 'ts_partitioned', 'run': 1, 'hj_load_ns': 140528256, 'hj_exec_ns': 84540075}, {'workload': 'hget_ratio000', 'hash_join_table_type': 'ts_partitioned_read_repair', 'run': 1, 'hj_load_ns': 139562256, 'hj_exec_ns': 107546554}, {'workload': 'hget_ratio000', 'hash_join_table_type': 'no_partition', 'run': 1, 'hj_load_ns': 116863169, 'hj_exec_ns': 331142715}, {'workload': 'hget_ratio000', 'hash_join_table_type': 'no_partition_read_repair', 'run': 1, 'hj_load_ns': 117366218, 'hj_exec_ns': 140735263}, {'workload': 'hget_ratio020', 'hash_join_table_type': 'ts_partitioned', 'run': 1, 'hj_load_ns': 139867244, 'hj_exec_ns': 86983969}, {'workload': 'hget_ratio020', 'hash_join_table_type': 'ts_partitioned_read_repair', 'run': 1, 'hj_load_ns': 148718817, 'hj_exec_ns': 105389526}, {'workload': 'hget_ratio020', 'hash_join_table_type': 'no_partition', 'run': 1, 'hj_load_ns': 119496791, 'hj_exec_ns': 313220033}, {'workload': 'hget_ratio020', 'hash_join_table_type': 'no_partition_read_repair', 'run': 1, 'hj_load_ns': 118624237, 'hj_exec_ns': 135211427}, {'workload': 'hget_ratio040', 'hash_join_table_type': 'ts_partitioned', 'run': 1, 'hj_load_ns': 140738517, 'hj_exec_ns': 89520899}, {'workload': 'hget_ratio040', 'hash_join_table_type': 'ts_partitioned_read_repair', 'run': 1, 'hj_load_ns': 141840950, 'hj_exec_ns': 113614065}, {'workload': 'hget_ratio040', 'hash_join_table_type': 'no_partition', 'run': 1, 'hj_load_ns': 118542650, 'hj_exec_ns': 350659333}, {'workload': 'hget_ratio040', 'hash_join_table_type': 'no_partition_read_repair', 'run': 1, 'hj_load_ns': 119527104, 'hj_exec_ns': 147080764}, {'workload': 'hget_ratio060', 'hash_join_table_type': 'ts_partitioned', 'run': 1, 'hj_load_ns': 139796326, 'hj_exec_ns': 87989068}, {'workload': 'hget_ratio060', 'hash_join_table_type': 'ts_partitioned_read_repair', 'run': 1, 'hj_load_ns': 143224188, 'hj_exec_ns': 108608144}, {'workload': 'hget_ratio060', 'hash_join_table_type': 'no_partition', 'run': 1, 'hj_load_ns': 117101456, 'hj_exec_ns': 358268378}, {'workload': 'hget_ratio060', 'hash_join_table_type': 'no_partition_read_repair', 'run': 1, 'hj_load_ns': 117132044, 'hj_exec_ns': 144730465}, {'workload': 'hget_ratio080', 'hash_join_table_type': 'ts_partitioned', 'run': 1, 'hj_load_ns': 139114596, 'hj_exec_ns': 92438609}, {'workload': 'hget_ratio080', 'hash_join_table_type': 'ts_partitioned_read_repair', 'run': 1, 'hj_load_ns': 139353542, 'hj_exec_ns': 106710974}, {'workload': 'hget_ratio080', 'hash_join_table_type': 'no_partition', 'run': 1, 'hj_load_ns': 117303467, 'hj_exec_ns': 358353721}, {'workload': 'hget_ratio080', 'hash_join_table_type': 'no_partition_read_repair', 'run': 1, 'hj_load_ns': 117104727, 'hj_exec_ns': 137597682}, {'workload': 'hget_ratio100', 'hash_join_table_type': 'ts_partitioned', 'run': 1, 'hj_load_ns': 139700825, 'hj_exec_ns': 87899906}, {'workload': 'hget_ratio100', 'hash_join_table_type': 'ts_partitioned_read_repair', 'run': 1, 'hj_load_ns': 138427268, 'hj_exec_ns': 104412925}, {'workload': 'hget_ratio100', 'hash_join_table_type': 'no_partition', 'run': 1, 'hj_load_ns': 117835211, 'hj_exec_ns': 357854071}, {'workload': 'hget_ratio100', 'hash_join_table_type': 'no_partition_read_repair', 'run': 1, 'hj_load_ns': 117378226, 'hj_exec_ns': 138930229}]
# Averaged Results:
# Workload: hget_ratio000
#   MvccHashJoinTable: load=116.86 ms, exec=331.14 ms
# Workload: hget_ratio000
#   MvccHashJoinTable: load=117.37 ms, exec=140.74 ms
# Workload: hget_ratio000
#   MvccHashJoinTable: load=140.53 ms, exec=84.54 ms
# Workload: hget_ratio000
#   MvccHashJoinTable: load=139.56 ms, exec=107.55 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=119.50 ms, exec=313.22 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=118.62 ms, exec=135.21 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=139.87 ms, exec=86.98 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=148.72 ms, exec=105.39 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=140.74 ms, exec=89.52 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=141.84 ms, exec=113.61 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=118.54 ms, exec=350.66 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=119.53 ms, exec=147.08 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=117.10 ms, exec=358.27 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=117.13 ms, exec=144.73 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=139.80 ms, exec=87.99 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=143.22 ms, exec=108.61 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=117.30 ms, exec=358.35 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=117.10 ms, exec=137.60 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=139.11 ms, exec=92.44 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=139.35 ms, exec=106.71 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=139.70 ms, exec=87.90 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=117.84 ms, exec=357.85 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=117.38 ms, exec=138.93 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=138.43 ms, exec=104.41 ms

# %% [markdown]
# # if plot has outlier, use "y_limit" to cut plot, so that the plot is more readable

# %%
 # Compute means and standard deviations for each workload
stats = df.groupby(['workload', 'hash_join_table_type']).agg({
    'hj_load_ns': ['mean', 'std'],
    'hj_exec_ns': ['mean', 'std'],
})

# Flatten the MultiIndex columns
stats.columns = [
    'hj_load_mean', 'hj_load_std',
    'hj_exec_mean', 'hj_exec_std',
]
stats = stats.reset_index()
stats = stats.sort_values('workload')

# Convert nanoseconds to milliseconds for readability
stats['hj_load_mean_ms'] = stats['hj_load_mean'] / 1_000_000
stats['hj_exec_mean_ms'] = stats['hj_exec_mean'] / 1_000_000

# Print the averaged results
print("Averaged Results:")
for i, row in stats.iterrows():
    print(f"Workload: {row['workload']}")
    print(f"  MvccHashJoinTable: load={row['hj_load_mean_ms']:.2f} ms, exec={row['hj_exec_mean_ms']:.2f} ms")

# 1) Plot Execution Times Comparison

plt.figure(figsize=(10,6))
y_limit = 300
plt.ylim(0, y_limit)
bar_width = 0.2
workloads = stats['workload'].unique()
X = range(len(workloads))

for hash_join_table_type, group in stats.groupby('hash_join_table_type'):
    plt.errorbar(X, group['hj_exec_mean_ms'], yerr=group['hj_exec_std']/1_000_000, fmt='o-', label=f'{hash_join_table_type} Exec')

plt.xticks(X, workloads, rotation=45)
plt.xlabel('Workload')
plt.ylabel('Execution Time (ms)')
plt.title('Benchmark Comparison (Execution Times)')
plt.legend()

for i, workload in enumerate(workloads):
    for hash_join_table_type, group in stats.groupby('hash_join_table_type'):
        y_val = group[group['workload'] == workload]['hj_exec_mean_ms'].values[0]
        if y_val < y_limit:
            plt.text(i, y_val + 0.05, f"{y_val:.2f} ms", ha='center', color='orange')

plt.tight_layout()
plt.show()
# Out:
# Averaged Results:
# Workload: hget_ratio000
#   MvccHashJoinTable: load=3062.91 ms, exec=13.83 ms
# Workload: hget_ratio000
#   MvccHashJoinTable: load=1710.34 ms, exec=11647.84 ms
# Workload: hget_ratio000
#   MvccHashJoinTable: load=1278.98 ms, exec=42.36 ms
# Workload: hget_ratio000
#   MvccHashJoinTable: load=1514.27 ms, exec=107.06 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=3678.67 ms, exec=56.34 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=2182.04 ms, exec=12878.71 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=2327.23 ms, exec=31.84 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=1541.73 ms, exec=106.73 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=1233.72 ms, exec=26.84 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=1479.75 ms, exec=108.34 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=2636.15 ms, exec=75.37 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=2067.99 ms, exec=11364.06 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=2502.67 ms, exec=106.10 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=1859.45 ms, exec=11720.90 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=1399.55 ms, exec=45.56 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=1636.04 ms, exec=108.85 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=2806.94 ms, exec=180.53 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=1878.78 ms, exec=13271.00 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=1333.59 ms, exec=34.68 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=1722.42 ms, exec=107.64 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=1343.25 ms, exec=34.93 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=2843.55 ms, exec=203.40 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=1831.38 ms, exec=11377.73 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=1905.07 ms, exec=114.99 ms

# %%
import os
import subprocess
import glob
import pandas as pd
import matplotlib.pyplot as plt
import re
from IPython.display import display, Markdown

# Use the custom style
plt.style.use('../custom_plt_sytle.mplstyle')

# Number of runs per workload
# number_of_runs = 1
# entries= 10000
# versions = 100

csv_dir = format("./csv_%dentries_%dversions" % (entries, versions))
print(f"csv_dir is {csv_dir}")
# Build the binary to ensure it's up-to-date
print("Building hash_join_bench with cargo build --release...")
myenv = os.environ.copy()
myenv["RUSTFLAGS"] = "-Awarnings"
subprocess.run(['cargo', 'build', '--release', '--bin', 'hash_join_bench_mixed_get'], check=True, env=myenv)
print("Build completed.")

binary = '../../../target/release/hash_join_bench_mixed_get'
data_file_prefix = os.path.join(csv_dir, 'data_multiversion.csv')
scan_ops_file = os.path.join(csv_dir, 'scan_ops.csv')

# Find all workload ops files in csv directory
ops_files = glob.glob(os.path.join(csv_dir, '*_ops.csv'))
ops_files.sort()

results = []  # will hold dicts of {workload, run, rust_load_ns, hj_load_ns, rust_exec_ns, hj_exec_ns, recent_get_ns, history_get_ns}
hash_join_table_type_list = ['chain', 'open_address', 'rust', 'heap', 'linear']
for ops_path in ops_files:
    workload_name = os.path.splitext(os.path.basename(ops_path))[0].replace('_ops','')
    
    for hash_join_table_type in hash_join_table_type_list:
        # Run the benchmark multiple times for each workload
        for run_id in range(1, number_of_runs+1):
            print(f"Running benchmark for workload {workload_name}, table type {hash_join_table_type}, run {run_id}...")
            cmd = [
                binary,
                '-df', data_file_prefix,
                '-of', ops_path,
                '-t', hash_join_table_type
            ]

            print("cmd:", cmd)

            completed = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
            if completed.returncode != 0:
                print(f"Benchmark failed for workload {workload_name}, run {run_id}:")
                print(completed.stderr)
                continue

            output = completed.stdout
            # print("benchmark run output:", output)

            # Parse other times (loading and execution times)
            hj_load_time_ns = None
            hj_execute_time_ns = None

            for line in output.splitlines():
                if line.startswith("Loaded") and "HashJoinTable" in line:
                    m = re.search(r'Loaded (\d+) entries with (\d+) versions into HashJoinTable in (\d+) ns', line)
                    if m:
                        hj_load_time_ns = int(m.group(3))
                elif line.startswith("HashJoinTable: Executed"):
                    m = re.search(r'Executed \d+ operations in (\d+) ns', line)
                    if m:
                        hj_execute_time_ns = int(m.group(1))

            if (hj_execute_time_ns is None or hj_load_time_ns is None):
                print("Warning: Could not parse all times from output for this run:")
                print(output)
            else:
                results.append({
                    'workload': workload_name,
                    'hash_join_table_type': hash_join_table_type,
                    'run': run_id,
                    'hj_load_ns': hj_load_time_ns,
                    'hj_exec_ns': hj_execute_time_ns,
                })

print("Benchmarking completed.")
print("results:", results)
df = pd.DataFrame(results)

if df.empty:
    print("No results were parsed. Check the output format or regex patterns.")
else:
    # Compute means and standard deviations for each workload
    stats = df.groupby(['workload', 'hash_join_table_type']).agg({
        'hj_load_ns': ['mean', 'std'],
        'hj_exec_ns': ['mean', 'std'],
    })

    # Flatten the MultiIndex columns
    stats.columns = [
        'hj_load_mean', 'hj_load_std',
        'hj_exec_mean', 'hj_exec_std',
    ]
    stats = stats.reset_index()
    stats = stats.sort_values('workload')

    # Convert nanoseconds to milliseconds for readability
    stats['hj_load_mean_ms'] = stats['hj_load_mean'] / 1_000_000
    stats['hj_exec_mean_ms'] = stats['hj_exec_mean'] / 1_000_000

    # Print the averaged results
    print("Averaged Results:")
    for i, row in stats.iterrows():
        print(f"Workload: {row['workload']}")
        print(f"  MvccHashJoinTable: load={row['hj_load_mean_ms']:.2f} ms, exec={row['hj_exec_mean_ms']:.2f} ms")

    # 1) Plot Execution Times Comparison
    plt.figure(figsize=(10,6))
    bar_width = 0.2
    workloads = stats['workload'].unique()
    X = range(len(workloads))

    for hash_join_table_type, group in stats.groupby('hash_join_table_type'):
        plt.errorbar(X, group['hj_exec_mean_ms'], yerr=group['hj_exec_std']/1_000_000, fmt='o-', label=f'{hash_join_table_type} Exec')

    plt.xticks(X, workloads, rotation=45)
    plt.xlabel('Workload')
    plt.ylabel('Execution Time (ms)')
    plt.title('Benchmark Comparison (Execution Times)')
    plt.legend()

    for i, workload in enumerate(workloads):
        for hash_join_table_type, group in stats.groupby('hash_join_table_type'):
            y_val = group[group['workload'] == workload]['hj_exec_mean_ms'].values[0]
            plt.text(i, y_val + 0.05, f"{y_val:.2f} ms", ha='center', color='orange')

    plt.tight_layout()
    plt.show()

    # 2) Plot Loading Times Comparison
    plt.figure(figsize=(10,6))

    for hash_join_table_type, group in stats.groupby('hash_join_table_type'):
        plt.errorbar(X, group['hj_load_mean_ms'], yerr=group['hj_load_std']/1_000_000, fmt='o-', label=f'{hash_join_table_type} Load')

    plt.xticks(X, workloads, rotation=45)
    plt.xlabel('Workload')
    plt.ylabel('Loading Time (ms)')
    plt.title('Benchmark Comparison (Loading Times)')
    plt.legend()

    for i, workload in enumerate(workloads):
        for hash_join_table_type, group in stats.groupby('hash_join_table_type'):
            y_val = group[group['workload'] == workload]['hj_load_mean_ms'].values[0]
            plt.text(i, y_val + 0.05, f"{y_val:.2f} ms", ha='center', color='orange')

    plt.tight_layout()
    plt.show()
# Out:
# csv_dir is ./csv_10000entries_100versions
# Building hash_join_bench with cargo build --release...
# Build completed.
# Benchmarking completed.
# results: []
# No results were parsed. Check the output format or regex patterns.
#     Finished `release` profile [optimized + debuginfo] target(s) in 0.05s

# %%
 # Compute means and standard deviations for each workload
stats = df.groupby(['workload', 'hash_join_table_type']).agg({
    'hj_load_ns': ['mean', 'std'],
    'hj_exec_ns': ['mean', 'std'],
})

# Flatten the MultiIndex columns
stats.columns = [
    'hj_load_mean', 'hj_load_std',
    'hj_exec_mean', 'hj_exec_std',
]
stats = stats.reset_index()
stats = stats.sort_values('workload')

# Convert nanoseconds to milliseconds for readability
stats['hj_load_mean_ms'] = stats['hj_load_mean'] / 1_000_000
stats['hj_exec_mean_ms'] = stats['hj_exec_mean'] / 1_000_000

# Print the averaged results
print("Averaged Results:")
for i, row in stats.iterrows():
    print(f"Workload: {row['workload']}")
    print(f"  MvccHashJoinTable: load={row['hj_load_mean_ms']:.2f} ms, exec={row['hj_exec_mean_ms']:.2f} ms")

# 1) Plot Execution Times Comparison

plt.figure(figsize=(10,6))
y_limit = 3000
# plt.ylim(0, y_limit)
bar_width = 0.2
workloads = stats['workload'].unique()
X = range(len(workloads))

for hash_join_table_type, group in stats.groupby('hash_join_table_type'):
    plt.errorbar(X, group['hj_exec_mean_ms'], yerr=group['hj_exec_std']/1_000_000, fmt='o-', label=f'{hash_join_table_type} Exec')

plt.xticks(X, workloads, rotation=45)
plt.xlabel('Workload')
plt.ylabel('Execution Time (ms)')
plt.title('Benchmark Comparison (Execution Times)')
plt.legend()

for i, workload in enumerate(workloads):
    for hash_join_table_type, group in stats.groupby('hash_join_table_type'):
        y_val = group[group['workload'] == workload]['hj_exec_mean_ms'].values[0]
        if y_val < y_limit:
            plt.text(i, y_val + 0.05, f"{y_val:.2f} ms", ha='center', color='orange')

plt.tight_layout()
plt.show()
# Out:
# Averaged Results:
# Workload: hget_ratio000
#   MvccHashJoinTable: load=0.50 ms, exec=2.01 ms
# Workload: hget_ratio000
#   MvccHashJoinTable: load=0.39 ms, exec=6.95 ms
# Workload: hget_ratio000
#   MvccHashJoinTable: load=0.56 ms, exec=1.97 ms
# Workload: hget_ratio000
#   MvccHashJoinTable: load=0.55 ms, exec=2.50 ms
# Workload: hget_ratio000
#   MvccHashJoinTable: load=0.59 ms, exec=0.84 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=0.49 ms, exec=2.36 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=0.33 ms, exec=5.93 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=0.51 ms, exec=1.93 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=0.58 ms, exec=3.08 ms
# Workload: hget_ratio020
#   MvccHashJoinTable: load=0.42 ms, exec=0.73 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=0.55 ms, exec=3.52 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=0.51 ms, exec=2.27 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=0.45 ms, exec=0.85 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=0.51 ms, exec=2.66 ms
# Workload: hget_ratio040
#   MvccHashJoinTable: load=0.31 ms, exec=5.80 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=0.51 ms, exec=3.04 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=0.33 ms, exec=5.86 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=0.52 ms, exec=2.56 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=0.56 ms, exec=4.06 ms
# Workload: hget_ratio060
#   MvccHashJoinTable: load=0.44 ms, exec=0.84 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=0.46 ms, exec=0.88 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=0.57 ms, exec=4.53 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=0.35 ms, exec=5.99 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=0.52 ms, exec=3.34 ms
# Workload: hget_ratio080
#   MvccHashJoinTable: load=0.50 ms, exec=2.78 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=0.60 ms, exec=5.07 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=0.49 ms, exec=3.44 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=0.32 ms, exec=5.79 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=0.49 ms, exec=2.93 ms
# Workload: hget_ratio100
#   MvccHashJoinTable: load=0.49 ms, exec=0.94 ms
